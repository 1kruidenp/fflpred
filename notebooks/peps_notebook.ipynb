# %%
import pandas as pd

# %% [markdown]
# # Assigning a player position to each player

# %%
from merge_years.import_data import get_full_data

# %%
df=get_full_data('../raw_data')
df.shape
# Out:
# (114861, 33)

# %%
df['name']=df.name.str.lower()

# %%
df[df['name']=='caglar söyüncü']
# Out:
#                  name  assists  bonus  bps  clean_sheets  creativity  element  \
# 84     caglar söyüncü        0      0    0             0         0.0      515
# 609    caglar söyüncü        0      0    0             0         0.0      515
# 1137   caglar söyüncü        0      0    0             0         0.0      515
# 1669   caglar söyüncü        0      0    0             0         0.0      515
# 2206   caglar söyüncü        0      0    0             0         0.0      515
# 2744   caglar söyüncü        0      0    0             0         0.0      515
# 3282   caglar söyüncü        0      0    0             0         0.0      515
# 3821   caglar söyüncü        0      0    0             0         0.0      515
# 4364   caglar söyüncü        0      0    0             0         0.0      515
# 4910   caglar söyüncü        0      0    6             0         0.9      515
# 5458   caglar söyüncü        0      0    0             0         0.0      515
# 6008   caglar söyüncü        0      0    3             0         0.2      515
# 6560   caglar söyüncü        0      0    0             0         0.0      515
# 7114   caglar söyüncü        0      0    4             0         0.1      515
# 7670   caglar söyüncü        0      0    9             0         0.2      515
# 8229   caglar söyüncü        0      0    0             0         0.0      515
# 8789   caglar söyüncü        0      0    0             0         0.0      515
# 9353   caglar söyüncü        0      0    0             0         0.0      515
# 9919   caglar söyüncü        0      0    0             0         0.0      515
# 10487  caglar söyüncü        0      0   15             0         0.8      515
# 11055  caglar söyüncü        0      0    0             0         0.0      515
# 11625  caglar söyüncü        0      0    0             0         0.0      515
# 12199  caglar söyüncü        0      0    0             0         0.0      515
# 12777  caglar söyüncü        0      0    0             0         0.0      515
# 13372  caglar söyüncü        0      0    0             0         0.0      515
# 14016  caglar söyüncü        0      0    0             0         0.0      515
#
#        fixture  goals_conceded  goals_scored  ...  threat  total_points  \
# 84           6               0             0  ...     0.0             0
# 609         17               0             0  ...     0.0             0
# 1137        28               0             0  ...     0.0             0
# 1669        37               0             0  ...     0.0             0
# 2206        41               0             0  ...     0.0             0
# 2744        57               0             0  ...     0.0             0
# 3282        68               0             0  ...     0.0             0
# 3821        75               0             0  ...     0.0             0
# 4364        81               0             0  ...     0.0             0
# 4910        95               1             0  ...     0.0             1
# 5458       103               0             0  ...     0.0             0
# 6008       116               0             0  ...     0.0             1
# 6560       122               0             0  ...     0.0             0
# 7114       136               0             0  ...     0.0             1
# 7670       144               1             0  ...    22.0             2
# 8229       157               0             0  ...     0.0             0
# 8789       162               0             0  ...     0.0             0
# 9353       174               0             0  ...     0.0             0
# 9919       185               0             0  ...     0.0             0
# 10487      195               1             0  ...     0.0             2
# 11055      205               0             0  ...     0.0             0
# 11625      217               0             0  ...     0.0             0
# 12199      230               0             0  ...     0.0             0
# 12777      237               0             0  ...     0.0             0
# 13372      247               0             0  ...     0.0             0
# 14016      258               0             0  ...     0.0             0
#
#       transfers_balance  transfers_in  transfers_out  value  was_home  \
# 84                    0             0              0     50     False
# 609                -768           148            916     50      True
# 1137               -947            36            983     50     False
# 1669               -460            24            484     50      True
# 2206               -212            51            263     50     False
# 2744                -83            32            115     50      True
# 3282               -102            28            130     50     False
# 3821                -61            25             86     50      True
# 4364                -70            39            109     49     False
# 4910                -28            33             61     49      True
# 5458                 -1            48             49     49     False
# 6008                -16            42             58     49      True
# 6560                -14            51             65     49     False
# 7114                -18            20             38     49      True
# 7670                -17            16             33     49     False
# 8229                  2            30             28     49      True
# 8789                -15            40             55     49     False
# 9353                -25            22             47     49     False
# 9919                -32            27             59     49      True
# 10487               -14            40             54     49      True
# 11055                10            52             42     49     False
# 11625               -16            41             57     49      True
# 12199               -41            25             66     49     False
# 12777               -35            18             53     49     False
# 13372                -4            19             23     49      True
# 14016               -24            15             39     49     False
#
#        yellow_cards  GW  season
# 84                0   1      19
# 609               0   2      19
# 1137              0   3      19
# 1669              0   4      19
# 2206              0   5      19
# 2744              0   6      19
# 3282              0   7      19
# 3821              0   8      19
# 4364              0   9      19
# 4910              1  10      19
# 5458              0  11      19
# 6008              0  12      19
# 6560              0  13      19
# 7114              0  14      19
# 7670              0  15      19
# 8229              0  16      19
# 8789              0  17      19
# 9353              0  18      19
# 9919              0  19      19
# 10487             0  20      19
# 11055             0  21      19
# 11625             0  22      19
# 12199             0  23      19
# 12777             0  24      19
# 13372             0  25      19
# 14016             0  26      19
#
# [26 rows x 33 columns]

# %%
df[df['name']=='çaglar söyüncü']
# Out:
#                  name  assists  bonus  bps  clean_sheets  creativity  element  \
# 424    çaglar söyüncü        0      0   29             1         1.4      238
# 962    çaglar söyüncü        0      0   17             0        20.9      238
# 1516   çaglar söyüncü        0      0    4             0         0.5      238
# 2078   çaglar söyüncü        0      0   14             0         1.8      238
# 2661   çaglar söyüncü        0      0    0             0         0.0      238
# ...               ...      ...    ...  ...           ...         ...      ...
# 19076  çaglar söyüncü        0      0    0             0         0.0      515
# 19934  çaglar söyüncü        0      0    0             0         0.0      515
# 20549  çaglar söyüncü        0      0    0             0         0.0      515
# 21165  çaglar söyüncü        0      0    0             0         0.0      515
# 21789  çaglar söyüncü        0      0    0             0         0.0      515
#
#        fixture  goals_conceded  goals_scored  ...  threat  total_points  \
# 424          5               0             0  ...     6.0             6
# 962         14               2             0  ...    36.0             1
# 1516        24               2             0  ...     2.0             0
# 2078        34               3             0  ...     0.0             1
# 2661        43               0             0  ...     0.0             0
# ...        ...             ...           ...  ...     ...           ...
# 19076      335               0             0  ...     0.0             0
# 19934      349               0             0  ...     0.0             0
# 20549      355               0             0  ...     0.0             0
# 21165      367               0             0  ...     0.0             0
# 21789      375               0             0  ...     0.0             0
#
#       transfers_balance  transfers_in  transfers_out  value  was_home  \
# 424                   0             0              0     55     False
# 962              -16165         41879          58044     55      True
# 1516             -95807         30897         126704     55     False
# 2078             -64334         19529          83863     55      True
# 2661            -153786          8685         162471     55      True
# ...                 ...           ...            ...    ...       ...
# 19076                27            43             16     48      True
# 19934               -17            13             30     48     False
# 20549                -3            10             13     48      True
# 21165               -13             4             17     48     False
# 21789                -1            11             12     48      True
#
#        yellow_cards  GW  season
# 424               0   1      21
# 962               0   2      21
# 1516              1   3      21
# 2078              0   4      21
# 2661              0   5      21
# ...             ...  ..     ...
# 19076             0  34      19
# 19934             0  35      19
# 20549             0  36      19
# 21165             0  37      19
# 21789             0  38      19
#
# [88 rows x 33 columns]

# %%
#name_dict={'caglar söyüncü':'çaglar söyüncü'}

#df.apply(lambda row:row['name']='çaglar söyüncü' if row['name']=='caglar söyüncü')

# %%
for i,row in df.iterrows():
    if row['element']==515 and row['season']==19:
        df['name'].at[i]='çaglar söyüncü'

# %%
df[df['name']=='çaglar söyüncü']
# Out:
#                  name  assists  bonus  bps  clean_sheets  creativity  element  \
# 84     çaglar söyüncü        1      0   23             1        18.3      469
# 424    çaglar söyüncü        0      0   29             1         1.4      238
# 609    çaglar söyüncü        0      0    0             0         0.0       53
# 962    çaglar söyüncü        0      0   17             0        20.9      238
# 1137   çaglar söyüncü        0      0   -1             0        11.9      287
# ...               ...      ...    ...  ...           ...         ...      ...
# 19076  çaglar söyüncü        0      0    0             0         0.0      529
# 19934  çaglar söyüncü        0      0    3             0         0.7      678
# 20549  çaglar söyüncü        0      0    5             0         2.7       44
# 21165  çaglar söyüncü        0      0    0             0         0.0      360
# 21789  çaglar söyüncü        0      0   17             1        30.8      312
#
#        fixture  goals_conceded  goals_scored  ...  threat  total_points  \
# 84           8               0             0  ...     0.0             6
# 424          5               0             0  ...     6.0             6
# 609         16               0             0  ...     0.0             0
# 962         14               2             0  ...    36.0             1
# 1137        24               2             0  ...     1.0             1
# ...        ...             ...           ...  ...     ...           ...
# 19076      336               0             0  ...     0.0             0
# 19934      375               0             0  ...     0.0             1
# 20549       32               0             0  ...     4.0             1
# 21165       48               0             0  ...     0.0             0
# 21789       59               0             0  ...    23.0             3
#
#       transfers_balance  transfers_in  transfers_out  value  was_home  \
# 84                    0             0              0     55     False
# 424                   0             0              0     55     False
# 609               -3976          1468           5444     50     False
# 962              -16165         41879          58044     55      True
# 1137             -12411          2916          15327     70      True
# ...                 ...           ...            ...    ...       ...
# 19076               279           364             85     39     False
# 19934                 0             0              0     45     False
# 20549             -2963           113           3076     53      True
# 21165             -1158           391           1549     44     False
# 21789            -11152          2429          13581     44     False
#
#        yellow_cards  GW  season
# 84                0   1      21
# 424               0   1      21
# 609               0   2      21
# 962               0   2      21
# 1137              0   3      21
# ...             ...  ..     ...
# 19076             0  37      17
# 19934             0  38      17
# 20549             0   4      17
# 21165             0   5      17
# 21789             0   6      17
#
# [266 rows x 33 columns]

# %%
df[df.name=='ben davies']
# Out:
#              name  assists  bonus  bps  clean_sheets  creativity  element  \
# 45     ben davies        0      0   15             0        35.5      395
# 483    ben davies        0      0    2             0         2.0      395
# 1022   ben davies        0      0   16             0        11.8      395
# 1577   ben davies        1      0   13             0         0.6      395
# 2141   ben davies        0      0    0             0         0.0      395
# ...           ...      ...    ...  ...           ...         ...      ...
# 20802  ben davies        0      0    1             0         0.9      386
# 21386  ben davies        0      0   10             0        13.6      386
# 21972  ben davies        0      0    0             0         0.0      386
# 22561  ben davies        0      0   21             0        15.0      386
# 23154  ben davies        0      0    0             0         0.0      386
#
#        fixture  goals_conceded  goals_scored  ...  threat  total_points  \
# 45           4               1             0  ...    36.0             2
# 483         17               2             0  ...     0.0             1
# 1022        26               1             0  ...     2.0             2
# 1577        35               0             0  ...     4.0             4
# 2141        47               0             0  ...     0.0             0
# ...        ...             ...           ...  ...     ...           ...
# 20802       49               0             0  ...     0.0             0
# 21386       55               1             0  ...     0.0             2
# 21972       68               0             0  ...     0.0             0
# 22561       80               1             0  ...    45.0             2
# 23154       82               0             0  ...     0.0             0
#
#       transfers_balance  transfers_in  transfers_out  value  was_home  \
# 45                    0             0              0     50      True
# 483              -12410         13490          25900     50     False
# 1022             -19850         15628          35478     50      True
# 1577             -24434          2873          27307     49     False
# 2141             -18380          8354          26734     49      True
# ...                 ...           ...            ...    ...       ...
# 20802              1860          2357            497     49      True
# 21386              -772           677           1449     49     False
# 21972               -72           672            744     49      True
# 22561              -647           388           1035     49     False
# 23154               335           745            410     49     False
#
#        yellow_cards  GW  season
# 45                0   1      21
# 483               0   2      21
# 1022              0   3      21
# 1577              0   4      21
# 2141              0   5      21
# ...             ...  ..     ...
# 20802             1   5      17
# 21386             0   6      17
# 21972             0   7      17
# 22561             0   8      17
# 23154             0   9      17
#
# [207 rows x 33 columns]

# %%
raw_data_path = '../raw_data'

raw21 = pd.read_csv(raw_data_path + '/2020-21/players_raw.csv', encoding='utf_8')
raw20 = pd.read_csv(raw_data_path + '/2019-20/players_raw.csv', encoding='utf_8')
raw19 = pd.read_csv(raw_data_path + '/2018-19/players_raw.csv', encoding='utf-8')
raw18 = pd.read_csv(raw_data_path + '/2017-18/players_raw.csv', encoding='utf-8')
raw17 = pd.read_csv(raw_data_path + '/2016-17/players_raw.csv', encoding='utf-8')

# %%
position_by_name={
    1:'GK',
    2:'DEF',
    3:'MID',
    4:'FWD'
}

raw_seasons=[raw17,raw18,raw19,raw20,raw21]
for season in raw_seasons:
    
    positions=map(lambda num:position_by_name[num], season['element_type'] )
    season['position']=list(positions)
    season['name']=season['first_name']+' '+season['second_name']
    season['name']=season['name'].str.lower()
    for i,row in season.iterrows():
        if row['name']=='caglar söyüncü':
            season['name'].at[i]='çaglar söyüncü'

    
for i,row in raw19.iterrows():
    if row['name']=='Danny Ward' and row['position']=='GK':
        raw19['position'].at[i]='MID'

# %%
raw19[raw19.name=='danny ward']
# Out:
#      assists  bonus  bps chance_of_playing_next_round  \
# 143        0      0   67                          100
# 339        0      0    0                         None
#
#     chance_of_playing_this_round  clean_sheets   code  cost_change_event  \
# 143                          100             0  75826                  0
# 339                         None             0  95463                  0
#
#      cost_change_event_fall  cost_change_start  ...  transfers_in  \
# 143                       0                 -2  ...         37215
# 339                       0                 -2  ...          1238
#
#      transfers_in_event  transfers_out  transfers_out_event  value_form  \
# 143                   0          46709                    0         0.1
# 339                   0           6344                    0         0.0
#
#     value_season  web_name  yellow_cards position        name
# 143          5.1      Ward             0      MID  danny ward
# 339          0.0      Ward             0       GK  danny ward
#
# [2 rows x 60 columns]

# %%
df17=df.loc[df['season'] == 17].copy()
abc=raw17[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df17=df17.join(abc, on=['name'])

df18=df.loc[df['season'] == 18].copy()
abc=raw18[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df18=df18.join(abc, on=['name'])

df19=df.loc[df['season'] == 19].copy()
abc=raw19[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df19=df19.join(abc, on=['name'])

df20=df.loc[df['season'] == 20].copy()
abc=raw20[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df20=df20.join(abc, on=['name'])

df21=df.loc[df['season'] == 21].copy()
abc=raw21[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df21=df21.join(abc, on=['name'])

complete_data = pd.concat([df17,df18,df19,df20,df21])

# %% [markdown]
# # Checking for players with the same name

# %%
seasons=[raw17,raw18,raw19,raw20,raw21]

raw17.name.value_counts()[raw17.name.value_counts()>1]
raw18.name.value_counts()[raw18.name.value_counts()>1]
raw19.name.value_counts()[raw19.name.value_counts()>1] #Danny Ward 2
raw20.name.value_counts()[raw20.name.value_counts()>1]
raw21.name.value_counts()[raw21.name.value_counts()>1] #Ben Davies 2
# Out:
# ben davies    2
# Name: name, dtype: int64

# %%
df21[df21.name=='ben davies']
# Out:
#              name  assists  bonus  bps  clean_sheets  creativity  element  \
# 45     ben davies        0      0   15             0        35.5      395
# 45     ben davies        0      0   15             0        35.5      395
# 483    ben davies        0      0    2             0         2.0      395
# 483    ben davies        0      0    2             0         2.0      395
# 1022   ben davies        0      0   16             0        11.8      395
# ...           ...      ...    ...  ...           ...         ...      ...
# 23532  ben davies        0      0    0             0         0.0      653
# 23889  ben davies        0      0    0             0         0.0      395
# 23889  ben davies        0      0    0             0         0.0      395
# 24244  ben davies        0      0    0             0         0.0      653
# 24244  ben davies        0      0    0             0         0.0      653
#
#        fixture  goals_conceded  goals_scored  ...  total_points  \
# 45           4               1             0  ...             2
# 45           4               1             0  ...             2
# 483         17               2             0  ...             1
# 483         17               2             0  ...             1
# 1022        26               1             0  ...             2
# ...        ...             ...           ...  ...           ...
# 23532      360               0             0  ...             0
# 23889      373               0             0  ...             0
# 23889      373               0             0  ...             0
# 24244      374               0             0  ...             0
# 24244      374               0             0  ...             0
#
#        transfers_balance transfers_in  transfers_out  value  was_home  \
# 45                     0            0              0     50      True
# 45                     0            0              0     50      True
# 483               -12410        13490          25900     50     False
# 483               -12410        13490          25900     50     False
# 1022              -19850        15628          35478     50      True
# ...                  ...          ...            ...    ...       ...
# 23532                -37           19             56     47     False
# 23889               -252          245            497     45     False
# 23889               -252          245            497     45     False
# 24244                 50          173            123     47      True
# 24244                 50          173            123     47      True
#
#        yellow_cards  GW  season  position
# 45                0   1      21       DEF
# 45                0   1      21       DEF
# 483               0   2      21       DEF
# 483               0   2      21       DEF
# 1022              0   3      21       DEF
# ...             ...  ..     ...       ...
# 23532             0  37      21       DEF
# 23889             0  38      21       DEF
# 23889             0  38      21       DEF
# 24244             0  38      21       DEF
# 24244             0  38      21       DEF
#
# [110 rows x 34 columns]

# %%
df19[df19.name=='danny ward']
# Out:
#              name  assists  bonus  bps  clean_sheets  creativity  element  \
# 126    danny ward        0      0    3             0         1.1      105
# 126    danny ward        0      0    3             0         1.1      105
# 127    danny ward        0      0    0             0         0.0      457
# 127    danny ward        0      0    0             0         0.0      457
# 651    danny ward        0      0    0             0         0.0      105
# ...           ...      ...    ...  ...           ...         ...      ...
# 20698  danny ward        0      0    0             0         0.0      457
# 21314  danny ward        0      0    2             0         2.6      105
# 21314  danny ward        0      0    2             0         2.6      105
# 21315  danny ward        0      0    0             0         0.0      457
# 21315  danny ward        0      0    0             0         0.0      457
#
#        fixture  goals_conceded  goals_scored  ...  total_points  \
# 126          2               1             0  ...             1
# 126          2               1             0  ...             1
# 127          6               0             0  ...             0
# 127          6               0             0  ...             0
# 651         13               0             0  ...             0
# ...        ...             ...           ...  ...           ...
# 20698      367               0             0  ...             0
# 21314      377               0             0  ...             1
# 21314      377               0             0  ...             1
# 21315      375               0             0  ...             0
# 21315      375               0             0  ...             0
#
#        transfers_balance transfers_in  transfers_out  value  was_home  \
# 126                    0            0              0     45     False
# 126                    0            0              0     45     False
# 127                    0            0              0     45     False
# 127                    0            0              0     45     False
# 651                 -834          871           1705     45      True
# ...                  ...          ...            ...    ...       ...
# 20698                -33           10             43     43     False
# 21314                -90           80            170     43     False
# 21314                -90           80            170     43     False
# 21315                -35           19             54     43      True
# 21315                -35           19             54     43      True
#
#        yellow_cards  GW  season  position
# 126               0   1      19       MID
# 126               0   1      19        GK
# 127               0   1      19       MID
# 127               0   1      19        GK
# 651               0   2      19       MID
# ...             ...  ..     ...       ...
# 20698             0  37      19        GK
# 21314             0  38      19       MID
# 21314             0  38      19        GK
# 21315             0  38      19       MID
# 21315             0  38      19        GK
#
# [152 rows x 34 columns]

# %%
complete_data.shape
# Out:
# (114992, 34)

# %%
complete_data.drop_duplicates(inplace=True)
complete_data.shape
#cannot drop duplicates as this will drop Ben Davies 
#Has the right shape but one of the Danny Wards is in the wrong position
# Out:
# (114937, 34)

# %%
df.shape
# Out:
# (114861, 33)

# %%
for i,row in complete_data.iterrows(): #Change the goalkeeper Danny Ward to the correct position.
    if row['name']=='danny ward' and row['element']==105:
        complete_data['position'].at[i]='GK'
        #complete_data['name'].at[i]='Danny Ward #2'

# %%
complete_data[complete_data.name=='danny ward']['position'].value_counts()
# Out:
# GK     225
# MID     38
# Name: position, dtype: int64

# %% [markdown]
# # Check that no players have a missing position

# %%
is_NaN = complete_data[['position']].isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = complete_data[row_has_NaN]
rows_with_NaN
# Out:
#                  name  assists  bonus  bps  clean_sheets  creativity  element  \
# 84     çaglar söyüncü        0      0    0             0         0.0      210
# 609    çaglar söyüncü        0      0    3             0         0.8       76
# 1137   çaglar söyüncü        0      0    0             0         0.0      415
# 1669   çaglar söyüncü        0      0    0             0         0.0      494
# 2206   çaglar söyüncü        0      0    0             0         0.0      132
# ...               ...      ...    ...  ...           ...         ...      ...
# 19076  çaglar söyüncü        0      0   20             1         1.5       13
# 19934  çaglar söyüncü        0      0    0             0         0.0       69
# 20549  çaglar söyüncü        0      0   10             0        18.9        8
# 21165  çaglar söyüncü        0      0    0             0         0.0      419
# 21789  çaglar söyüncü        2      2   46             0        43.0      247
#
#        fixture  goals_conceded  goals_scored  ...  total_points  \
# 84           8               0             0  ...             0
# 609         95               0             0  ...             1
# 1137       107               0             0  ...             0
# 1669       103               0             0  ...             0
# 2206       112               0             0  ...             0
# ...        ...             ...           ...  ...           ...
# 19076      373               0             0  ...             6
# 19934       41               0             0  ...             0
# 20549       60               2             0  ...             1
# 21165       66               0             0  ...             0
# 21789       76               2             1  ...            15
#
#        transfers_balance transfers_in  transfers_out  value  was_home  \
# 84                     0            0              0     45     False
# 609               -14629           82          14711     58     False
# 1137                -128           68            196     44     False
# 1669                 -27            2             29     45     False
# 2206                -124         1447           1571     47      True
# ...                  ...          ...            ...    ...       ...
# 19076               3922         4772            850     58     False
# 19934               -337           82            419     49     False
# 20549                787         2020           1233     50     False
# 21165                -24           67             91     54     False
# 21789             150812       178421          27609     80      True
#
#        yellow_cards  GW  season  position
# 84                0   1      17       NaN
# 609               0  10      17       NaN
# 1137              0  11      17       NaN
# 1669              0  11      17       NaN
# 2206              0  12      17       NaN
# ...             ...  ..     ...       ...
# 19076             0  38      18       NaN
# 19934             0   5      18       NaN
# 20549             0   6      18       NaN
# 21165             0   7      18       NaN
# 21789             0   8      18       NaN
#
# [76 rows x 34 columns]

# %%
import numpy as np

# %%
rows_with_NaN.replace(np.nan)
# Out:
#                  name  assists  bonus  bps  clean_sheets  creativity  element  \
# 84     çaglar söyüncü        0      0    0             0         0.0      210
# 609    çaglar söyüncü        0      0    3             0         0.8       76
# 1137   çaglar söyüncü        0      0    0             0         0.0      415
# 1669   çaglar söyüncü        0      0    0             0         0.0      494
# 2206   çaglar söyüncü        0      0    0             0         0.0      132
# ...               ...      ...    ...  ...           ...         ...      ...
# 19076  çaglar söyüncü        0      0   20             1         1.5       13
# 19934  çaglar söyüncü        0      0    0             0         0.0       69
# 20549  çaglar söyüncü        0      0   10             0        18.9        8
# 21165  çaglar söyüncü        0      0    0             0         0.0      419
# 21789  çaglar söyüncü        2      2   46             0        43.0      247
#
#        fixture  goals_conceded  goals_scored  ...  total_points  \
# 84           8               0             0  ...             0
# 609         95               0             0  ...             1
# 1137       107               0             0  ...             0
# 1669       103               0             0  ...             0
# 2206       112               0             0  ...             0
# ...        ...             ...           ...  ...           ...
# 19076      373               0             0  ...             6
# 19934       41               0             0  ...             0
# 20549       60               2             0  ...             1
# 21165       66               0             0  ...             0
# 21789       76               2             1  ...            15
#
#        transfers_balance transfers_in  transfers_out  value  was_home  \
# 84                     0            0              0     45     False
# 609               -14629           82          14711     58     False
# 1137                -128           68            196     44     False
# 1669                 -27            2             29     45     False
# 2206                -124         1447           1571     47      True
# ...                  ...          ...            ...    ...       ...
# 19076               3922         4772            850     58     False
# 19934               -337           82            419     49     False
# 20549                787         2020           1233     50     False
# 21165                -24           67             91     54     False
# 21789             150812       178421          27609     80      True
#
#        yellow_cards  GW  season  position
# 84                0   1      17       NaN
# 609               0  10      17       NaN
# 1137              0  11      17       NaN
# 1669              0  11      17       NaN
# 2206              0  12      17       NaN
# ...             ...  ..     ...       ...
# 19076             0  38      18       NaN
# 19934             0   5      18       NaN
# 20549             0   6      18       NaN
# 21165             0   7      18       NaN
# 21789             0   8      18       NaN
#
# [76 rows x 34 columns]

# %% [markdown]
# # USE THIS SELL ARMIN PLEASE REPEAT THIS CELL ARMIN

# %%
df=get_full_data('../raw_data') #Get the data, might not need this

df['name']=df.name.str.lower() #Set the names to lowercase

for i,row in df.iterrows(): #Change caglar to çaglar
    if row['element']==515 and row['season']==19: 
        df['name'].at[i]='çaglar söyüncü'

#GET ALL THE PLAYER RAW DATA, ENCODING SHOULD BE CORRECT
raw_data_path = '../raw_data'

raw21 = pd.read_csv(raw_data_path + '/2020-21/players_raw.csv', encoding='utf_8')
raw20 = pd.read_csv(raw_data_path + '/2019-20/players_raw.csv', encoding='utf_8')
raw19 = pd.read_csv(raw_data_path + '/2018-19/players_raw.csv', encoding='utf-8')
raw18 = pd.read_csv(raw_data_path + '/2017-18/players_raw.csv', encoding='utf-8')
raw17 = pd.read_csv(raw_data_path + '/2016-17/players_raw.csv', encoding='utf-8')


position_by_name={ #Dictionary to map element_type to position
    1:'GK',
    2:'DEF',
    3:'MID',
    4:'FWD'
}

raw_seasons=[raw17,raw18,raw19,raw20,raw21]

for season in raw_seasons: #Iterate through the different raw files
    
    positions=map(lambda num:position_by_name[num], season['element_type'] ) #Map the positions
    season['position']=list(positions) #Assign the map to new columns
    season['name']=season['first_name']+' '+season['second_name'] #Merge the first and second names of the raw players
    season['name']=season['name'].str.lower() #Set these names to lower
    for i,row in season.iterrows(): #Change caglar to çaglar
        if row['name']=='caglar söyüncü':
            season['name'].at[i]='çaglar söyüncü'

#Change the position of the GK Danny Ward to MID so that we have duplicates that we can drop
#We will change the position after dropping, 
#IMPORTANT DO NOT REMOVE THIS STEP WITHOUT REMOVING THE STEP OF CHANGING THE POSITION BACK AND VICE VERSA
for i,row in raw19.iterrows(): 
    if row['name']=='Danny Ward' and row['position']=='GK':
        raw19['position'].at[i]='MID'

#Here we split the data frame into the seasons and join the raw positions on the name 
df17=df.loc[df['season'] == 17].copy()
abc=raw17[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df17=df17.join(abc, on=['name'])

df18=df.loc[df['season'] == 18].copy()
abc=raw18[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df18=df18.join(abc, on=['name'])

df19=df.loc[df['season'] == 19].copy()
abc=raw19[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df19=df19.join(abc, on=['name'])

df20=df.loc[df['season'] == 20].copy()
abc=raw20[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df20=df20.join(abc, on=['name'])

df21=df.loc[df['season'] == 21].copy()
abc=raw21[['name','position']]
abc.set_index('name',drop=True,inplace=True)
df21=df21.join(abc, on=['name'])

#Reconcatenate the data into a complete dataset
complete_data = pd.concat([df17,df18,df19,df20,df21])

complete_data.drop_duplicates(inplace=True) #Drop the duplicates (Danny Ward and Ben Davies)

for i,row in complete_data.iterrows(): #Change the goalkeeper Danny Ward to the correct position.
    if row['name']=='danny ward' and row['element']==105:
        complete_data['position'].at[i]='GK'

# %%
complete_data.columns
# Out:
# Index(['name', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity',
#        'element', 'fixture', 'goals_conceded', 'goals_scored', 'ict_index',
#        'influence', 'kickoff_time', 'minutes', 'opponent_team', 'own_goals',
#        'penalties_missed', 'penalties_saved', 'red_cards', 'saves', 'selected',
#        'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW', 'season', 'position'],
#       dtype='object')

# %% [markdown]
# # Adding the opponent team skill level

# %%
df21=complete_data.loc[complete_data['season'] == 21].copy()

# %%
opponent_team_playing_home_21={
    1:1200,
    2:1100,
    3:1130,
    4:1060,
    5:1250,
    6:1090,
    7:1250,
    8:1090,
    9:1240,
    10:1160,
    11:1250,
    12:1340,
    13:1250,
    14:1050,
    15:1000,
    16:1060,
    17:1190,
    18:1050,
    19:1230,
    20:1080
}

opponent_team_playing_away_21={
    1:1250,
    2:1160,
    3:1130,
    4:1070,
    5:1280,
    6:1110,
    7:1130,
    8:1100,
    9:1260,
    10:1170,
    11:1210,
    12:1360,
    13:1320,
    14:1070,
    15:1040,
    16:1100,
    17:1250,
    18:1040,
    19:1260,
    20:1110
}


level=[]

for i,row in df21.iterrows():
    if row.was_home==True:
        level.append(opponent_team_playing_away_21[row['opponent_team']])
    else:
        level.append(opponent_team_playing_home_21[row['opponent_team']])

df21['opponent_level']=level

# %%
df21.head()
# Out:
#                  name  assists  bonus  bps  clean_sheets  creativity  element  \
# 0      aaron connolly        0      0   -3             0         0.3       78
# 1     aaron cresswell        0      0   11             0        11.2      435
# 2          aaron mooy        0      0    0             0         0.0       60
# 3      aaron ramsdale        0      0   12             0         0.0      483
# 4  abdoulaye doucouré        0      0   20             1        44.6      512
#
#    fixture  goals_conceded  goals_scored  ...  transfers_balance  \
# 0        7               2             0  ...                  0
# 1        6               2             0  ...                  0
# 2        7               0             0  ...                  0
# 3        8               2             0  ...                  0
# 4        4               0             0  ...                  0
#
#    transfers_in transfers_out  value  was_home  yellow_cards  GW  season  \
# 0             0             0     55      True             0   1      21
# 1             0             0     50      True             0   1      21
# 2             0             0     50      True             0   1      21
# 3             0             0     50      True             0   1      21
# 4             0             0     55     False             0   1      21
#
#    position  opponent_level
# 0       FWD            1280
# 1       DEF            1070
# 2       MID            1280
# 3        GK            1110
# 4       MID            1190
#
# [5 rows x 35 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(df21[['total_points','opponent_level']].groupby('opponent_level').mean())

# %%
df20=complete_data.loc[complete_data['season'] == 20].copy()

opponent_team_playing_home_20={
    1:1180,
    2:1020,
    3:1020,
    4:1050,
    5:1110,
    6:1220,
    7:1130,
    8:1100,
    9:1210,
    10:1340,
    11:1330,
    12:1220,
    13:1090,
    14:980,
    15:1180,
    16:1150,
    17:1180,
    18:1030,
    19:1040,
    20:1230
}

opponent_team_playing_away_20={
    1:1240,
    2:1050,
    3:1020,
    4:1010,
    5:1180,
    6:1230,
    7:1120,
    8:1240,
    9:1160,
    10:1350,
    11:1340,
    12:1300,
    13:1100,
    14:1020,
    15:1200,
    16:1040,
    17:1240,
    18:1140,
    19:1030,
    20:1190
}

level=[]

for i,row in df20.iterrows():
    if row.was_home==True:
        level.append(opponent_team_playing_away_20[row['opponent_team']])
    else:
        level.append(opponent_team_playing_home_20[row['opponent_team']])

df20['opponent_level']=level

# %%
plt.plot(df20[['total_points','opponent_level']].groupby('opponent_level').mean())

# %% [markdown]
# # Hi Armin Here is a new function to add!!! Sorry about the long dictionaries

# %%
opponent_team_playing_home_20={
    1:1180,
    2:1020,
    3:1020,
    4:1050,
    5:1110,
    6:1220,
    7:1130,
    8:1100,
    9:1210,
    10:1340,
    11:1330,
    12:1220,
    13:1090,
    14:980,
    15:1180,
    16:1150,
    17:1180,
    18:1030,
    19:1040,
    20:1230
}

opponent_team_playing_away_20={
    1:1240,
    2:1050,
    3:1020,
    4:1010,
    5:1180,
    6:1230,
    7:1120,
    8:1240,
    9:1160,
    10:1350,
    11:1340,
    12:1300,
    13:1100,
    14:1020,
    15:1200,
    16:1040,
    17:1240,
    18:1140,
    19:1030,
    20:1190
}

opponent_team_playing_home_21={
    1:1200,
    2:1100,
    3:1130,
    4:1060,
    5:1250,
    6:1090,
    7:1250,
    8:1090,
    9:1240,
    10:1160,
    11:1250,
    12:1340,
    13:1250,
    14:1050,
    15:1000,
    16:1060,
    17:1190,
    18:1050,
    19:1230,
    20:1080
}

opponent_team_playing_away_21={
    1:1250,
    2:1160,
    3:1130,
    4:1070,
    5:1280,
    6:1110,
    7:1130,
    8:1100,
    9:1260,
    10:1170,
    11:1210,
    12:1360,
    13:1320,
    14:1070,
    15:1040,
    16:1100,
    17:1250,
    18:1040,
    19:1260,
    20:1110
}

df17=df.loc[df['season'] == 17].copy()

df18=df.loc[df['season'] == 18].copy()

df19=df.loc[df['season'] == 19].copy()

df20=df.loc[df['season'] == 20].copy()
level=[]
for i,row in df20.iterrows():
    if row.was_home==True:
        level.append(opponent_team_playing_away_20[row['opponent_team']])
    else:
        level.append(opponent_team_playing_home_20[row['opponent_team']])
df20['opponent_level']=level

df21=df.loc[df['season'] == 21].copy()
level=[]
for i,row in df21.iterrows():
    if row.was_home==True:
        level.append(opponent_team_playing_away_21[row['opponent_team']])
    else:
        level.append(opponent_team_playing_home_21[row['opponent_team']])
df21['opponent_level']=level

complete_data = pd.concat([df17,df18,df19,df20,df21])

# %% [markdown]
# # The cost

# %%
complete_data.columns
# Out:
# Index(['name', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity',
#        'element', 'fixture', 'goals_conceded', 'goals_scored', 'ict_index',
#        'influence', 'kickoff_time', 'minutes', 'opponent_team', 'own_goals',
#        'penalties_missed', 'penalties_saved', 'red_cards', 'saves', 'selected',
#        'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW', 'season', 'opponent_level'],
#       dtype='object')

# %%
raw17[['dreamteam_count','name']][raw17.name=='harry kane']
# Out:
#      dreamteam_count        name
# 402                9  harry kane

# %%
'hakim ziyech' in raw21['name'].values
# Out:
# True

# %%
raw_list=[raw17,raw18,raw19,raw20,raw21]

def create_dreamteam_count_yearly(player='harry kane'):
    num_seasons=0
    yearly_dreamteam_count=0
    for i,raw in enumerate(raw_list):
        if i==len(raw_list)-1:
            break
        if player in raw['name'].values:
            num_seasons+=1
            yearly_dreamteam_count+=raw[['dreamteam_count']][raw.name==player].values[0][0]
    if num_seasons==0:
        return np.nan
    return yearly_dreamteam_count/num_seasons
    
create_dreamteam_count_yearly('hakim ziyech')
# Out:
# nan

# %%
def create_dreamteam_count_yearly(player='harry kane'):
    num_seasons=0
    yearly_dreamteam_count=0
    for i,raw in enumerate(raw_list):
        if i==len(raw_list)-1:
            break
        if player in raw['name'].values:
            num_seasons+=1
            yearly_dreamteam_count+=raw[['dreamteam_count']][raw.name==player].values[0][0]
    if num_seasons==0:
        return np.nan
    return yearly_dreamteam_count/num_seasons


df17=df.loc[df['season'] == 17].copy()
df18=df.loc[df['season'] == 18].copy()
df19=df.loc[df['season'] == 19].copy()
df20=df.loc[df['season'] == 20].copy()
df21=df.loc[df['season'] == 21].copy()

raw_list=[raw17,raw18,raw19,raw20,raw21]



complete_data = pd.concat([df17,df18,df19,df20,df21])
