# %%
from merge_years.import_data import get_full_data

# %%
df = get_full_data('../raw_data')

# %%
df
# Out:
#                   name  assists  bonus  bps  clean_sheets  creativity  \
# 0       aaron connolly        0      0    1             0         0.1
# 1       aaron connolly        0      0    1             0         0.3
# 2       aaron connolly        0      0    1             0         4.8
# 3       aaron connolly        0      0    2             0         0.6
# 4       aaron connolly        0      3   53             1        23.8
# ...                ...      ...    ...  ...           ...         ...
# 114987    ørjan nyland        0      0    0             0         0.0
# 114988    ørjan nyland        0      0    0             0         0.0
# 114989    ørjan nyland        0      0    0             0         0.0
# 114990    ørjan nyland        0      0    0             0         0.0
# 114991    ørjan nyland        0      0    0             0         0.0
#
#         element  fixture  goals_conceded  goals_scored  ...  value  was_home  \
# ...
