# %%
from merge_years.import_data import get_full_data

# %%
df = get_full_data('../raw_data')

# %%
pd.set

# %%
df.head(20)
# Out:
#               name  assists  bonus  bps  clean_sheets  creativity  element  \
# 0   aaron connolly        0      0    1             0         0.1      534
# 1   aaron connolly        0      0    1             0         0.3      534
# 2   aaron connolly        0      0    1             0         4.8      534
# 3   aaron connolly        0      0    2             0         0.6      534
# 4   aaron connolly        0      3   53             1        23.8      534
# 5   aaron connolly        0      0    3             0        10.6      534
# 6   aaron connolly        2      0   22             0         0.3      534
# 7   aaron connolly        0      0    2             1         5.8      534
# 8   aaron connolly        0      0   -5             0         1.3      534
# 9   aaron connolly        0      0    0             0         0.0      534
# 10  aaron connolly        0      0   -1             0         1.7      534
# ...

# %%
df.shape
# Out:
# (114992, 40)

# %%
df.to_pickle('../raw_data/final_dataset.pickle', protocol = 4)

# %%
ls
